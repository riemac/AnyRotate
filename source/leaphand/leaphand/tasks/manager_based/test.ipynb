# %% [markdown]
# ## LeapHand 运动学功能测试 (Jupyter Notebook)
#
# ### ⚠️ 重要使用说明
#
# **执行顺序**: 必须按照第1个 Cell → 第2个 Cell → 第3个 Cell → ... 顺序依次执行
#
# **限制**:
# 1. **第1个 Cell (启动 IsaacSim) 只能执行一次**, 重复执行会导致错误
# 2. 若需重新开始, 必须 **重启 Kernel** 并从第1个 Cell重新执行
# 3. 测试过程中 **不要随意重启 Kernel**
#
# **功能目标**:
# - 获取 LeapHand 各手指末端的位置和姿态
# - 测试坐标系转换 (World ↔ Body Frame)
# - 设置关节角度并观察末端变化

# %%
# Cell 1: 启动 IsaacSim 环境 (⚠️ 只能执行一次!)

print("正在启动 IsaacSim 环境...")

from isaaclab.app import AppLauncher
import argparse

# 方法: 使用 Namespace 对象 (兼容 AppLauncher)
args = argparse.Namespace(
    # === 可修改区域 ===
    headless=False,         # True: 无图形界面, False: 显示可视化
    device="cuda:0",        # 设备: "cuda:0", "cuda:1", "cpu" 等
    num_envs=1,             # 环境数量 (仅供本 Notebook 使用,非 AppLauncher 参数)
    # === 可修改区域结束 ===
    
    # AppLauncher 需要的其他参数 (保持默认)
    livestream=0,
    enable_cameras=False,
    verbose=False,
    experience=""
)

# 启动 IsaacSim (关键步骤,必须在其他导入前)
app_launcher = AppLauncher(args)
simulation_app = app_launcher.app

print(f"✅ IsaacSim 环境已启动!")
print(f"   - Headless 模式: {args.headless}")
print(f"   - 设备: {args.device}")
print(f"   - 环境数: {args.num_envs}")
# Cell 2: 导入所有依赖库

import torch
import numpy as np
import isaaclab.sim as sim_utils
import isaaclab.utils.math as math_utils
from isaaclab.assets import Articulation, ArticulationCfg
from isaaclab.scene import InteractiveScene, InteractiveSceneCfg
from isaaclab.sim import SimulationContext
from isaaclab.utils import configclass
from leaphand.robots.leap import LEAP_HAND_CFG

print("✅ 所有依赖导入完成!")
# Out:
# 正在启动 IsaacSim 环境...
# [INFO][AppLauncher]: Input keyword argument `livestream=0` has overridden the environment variable `LIVESTREAM=0`.
# [INFO][AppLauncher]: Using device: cuda:0
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# [INFO][AppLauncher]: Loading experience file: /home/hac/isaac/IsaacLab/apps/isaacsim_4_5/isaaclab.python.kit
# [Warning] [simulation_app.simulation_app] Modules: ['omni.kit_app'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [simulation_app.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# Loading user config located at: '/home/hac/isaac/.venv/lib/python3.10/site-packages/omni/data/Kit/Isaac-Sim/4.5/user.config.json'
# [Info] [carb] Logging to file: /home/hac/isaac/.venv/lib/python3.10/site-packages/omni/logs/Kit/Isaac-Sim/4.5/kit_20251110_144732.log
# 2025-11-10 06:47:32 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# 2025-11-10 06:47:32 s] [Warning] [omni.ext.plugin] [ext: rendering_modes] Extensions config 'extension.toml' doesn't exist '/home/hac/isaac/IsaacLab/apps/isaacsim_4_5/rendering_modes' or '/home/hac/isaac/IsaacLab/apps/isaacsim_4_5/rendering_modes/config'
# [0.063s] [ext: omni.kit.async_engine-0.0.1] startup
# [0.168s] [ext: omni.metrics.core-0.0.1] startup
# [0.168s] [ext: omni.client.lib-1.0.0] startup
# [0.193s] [ext: omni.blobkey-1.1.2] startup
# [0.193s] [ext: omni.stats-1.0.1] startup
# [0.194s] [ext: omni.datastore-0.0.0] startup
# [0.199s] [ext: omni.client-1.2.2] startup
# [0.254s] [ext: omni.ujitso.default-1.0.0] startup
# [0.256s] [ext: omni.hsscclient-1.1.1] startup
# [0.259s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.262s] [ext: omni.assets.plugins-0.0.0] startup
# [0.264s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.276s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.285s] [ext: omni.kit.renderer.init-0.0.0] startup
# [0.168s] [ext: omni.metrics.core-0.0.1] startup
# [0.168s] [ext: omni.client.lib-1.0.0] startup
# [0.193s] [ext: omni.blobkey-1.1.2] startup
# [0.193s] [ext: omni.stats-1.0.1] startup
# [0.194s] [ext: omni.datastore-0.0.0] startup
# [0.199s] [ext: omni.client-1.2.2] startup
# [0.254s] [ext: omni.ujitso.default-1.0.0] startup
# [0.256s] [ext: omni.hsscclient-1.1.1] startup
# [0.259s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.262s] [ext: omni.assets.plugins-0.0.0] startup
# [0.264s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.276s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.285s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.163.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060          | Yes: 0 |     | 8188    MB | 10de      | 0          |
# |     |                                  |        |     |            | 2808      | be6e39f1.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-86-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 15804 | Free Memory: 8233
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 9080
# |---------------------------------------------------------------------------------------------|
# [0.846s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.848s] [ext: omni.materialx.libs-1.0.6] startup
# [0.857s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.857s] [ext: omni.usd.config-1.0.5] startup
# [0.860s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.860s] [ext: omni.usd.libs-1.0.1] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.163.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060          | Yes: 0 |     | 8188    MB | 10de      | 0          |
# |     |                                  |        |     |            | 2808      | be6e39f1.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-86-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 15804 | Free Memory: 8233
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 9080
# |---------------------------------------------------------------------------------------------|
# [0.846s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.848s] [ext: omni.materialx.libs-1.0.6] startup
# [0.857s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.857s] [ext: omni.usd.config-1.0.5] startup
# [0.860s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.860s] [ext: omni.usd.libs-1.0.1] startup
# [0.941s] [ext: omni.mdl-55.0.1] startup
# [0.957s] [ext: omni.iray.libs-0.0.0] startup
# [0.966s] [ext: omni.mdl.neuraylib-0.2.10] startup
# [0.968s] [ext: omni.kit.usd.mdl-1.0.7] startup
# [1.064s] [ext: omni.kit.loop-isaac-1.2.1] startup
# [1.065s] [ext: omni.kit.test-1.1.2] startup
# [1.095s] [ext: omni.kit.telemetry-0.5.1] startup
# [1.116s] [ext: omni.appwindow-1.1.9] startup
# [0.941s] [ext: omni.mdl-55.0.1] startup
# [0.957s] [ext: omni.iray.libs-0.0.0] startup
# [0.966s] [ext: omni.mdl.neuraylib-0.2.10] startup
# [0.968s] [ext: omni.kit.usd.mdl-1.0.7] startup
# [1.064s] [ext: omni.kit.loop-isaac-1.2.1] startup
# [1.065s] [ext: omni.kit.test-1.1.2] startup
# [1.095s] [ext: omni.kit.telemetry-0.5.1] startup
# [1.116s] [ext: omni.appwindow-1.1.9] startup
# [1.423s] [ext: omni.kit.renderer.core-1.0.2] startup
# [1.423s] [ext: omni.kit.renderer.core-1.0.2] startup
# [2.724s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [2.728s] [ext: omni.kit.renderer.imgui-1.0.2] startup
# [2.803s] [ext: omni.ui-2.26.5] startup
# [2.813s] [ext: omni.kit.mainwindow-1.0.3] startup
# [2.815s] [ext: carb.audio-0.1.0] startup
# [2.818s] [ext: omni.uiaudio-1.0.0] startup
# [2.819s] [ext: omni.kit.uiapp-0.0.0] startup
# [2.820s] [ext: omni.usd.schema.metrics.assembler-106.5.0] startup
# [2.829s] [ext: isaacsim.robot.schema-3.1.2] startup
# [2.838s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [2.844s] [ext: omni.usd.schema.audio-0.0.0] startup
# [2.848s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [2.852s] [ext: omni.usd.schema.anim-0.0.0] startup
# [2.873s] [ext: omni.usd.schema.forcefield-106.5.7] startup
# [2.884s] [ext: omni.usd.schema.physx-106.5.7] startup
# [2.907s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [2.910s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [2.913s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [2.918s] [ext: omni.resourcemonitor-107.0.0] startup
# [2.920s] [ext: omni.activity.core-1.0.1] startup
# [2.922s] [ext: omni.timeline-1.0.11] startup
# [2.924s] [ext: omni.usd_resolver-1.0.0] startup
# [2.724s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [2.728s] [ext: omni.kit.renderer.imgui-1.0.2] startup
# [2.803s] [ext: omni.ui-2.26.5] startup
# [2.813s] [ext: omni.kit.mainwindow-1.0.3] startup
# [2.815s] [ext: carb.audio-0.1.0] startup
# [2.818s] [ext: omni.uiaudio-1.0.0] startup
# [2.819s] [ext: omni.kit.uiapp-0.0.0] startup
# [2.820s] [ext: omni.usd.schema.metrics.assembler-106.5.0] startup
# [2.829s] [ext: isaacsim.robot.schema-3.1.2] startup
# [2.838s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [2.844s] [ext: omni.usd.schema.audio-0.0.0] startup
# [2.848s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [2.852s] [ext: omni.usd.schema.anim-0.0.0] startup
# [2.873s] [ext: omni.usd.schema.forcefield-106.5.7] startup
# [2.884s] [ext: omni.usd.schema.physx-106.5.7] startup
# [2.907s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [2.910s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [2.913s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [2.918s] [ext: omni.resourcemonitor-107.0.0] startup
# [2.920s] [ext: omni.activity.core-1.0.1] startup
# [2.922s] [ext: omni.timeline-1.0.11] startup
# [2.924s] [ext: omni.usd_resolver-1.0.0] startup
# [2.929s] [ext: omni.kit.widget.nucleus_connector-1.1.10] startup
# [2.931s] [ext: usdrt.scenegraph-7.5.1] startup
# [2.973s] [ext: omni.usd.core-1.4.2] startup
# [2.976s] [ext: omni.kit.usd_undo-0.1.8] startup
# [2.976s] [ext: omni.graph.exec-0.9.4] startup
# [2.977s] [ext: omni.kit.actions.core-1.0.0] startup
# [2.979s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [2.981s] [ext: omni.kit.exec.core-0.13.4] startup
# [2.983s] [ext: omni.kit.commands-1.4.9] startup
# [2.988s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [3.000s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [3.007s] [ext: omni.usd-1.12.4] startup
# [3.061s] [ext: omni.kit.asset_converter-2.8.3] startup
# [3.081s] [ext: omni.volume-0.5.0] startup
# [3.089s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [3.091s] [ext: omni.index.libs-380600.1777.0] startup
# [3.091s] [ext: omni.ujitso.client-0.0.0] startup
# [3.091s] [ext: omni.index-1.0.1] startup
# [3.093s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [3.095s] [ext: omni.ui.scene-1.11.2] startup
# [3.101s] [ext: omni.hydra.rtx-1.0.0] startup
# 2025-11-10 06:47:35 [3,092ms] [Warning] [omni.log] Source: omni.hydra was already registered.
# [3.124s] [ext: omni.kit.menu.core-1.1.2] startup
# [3.125s] [ext: omni.kit.viewport.scene_camera_model-1.0.5] startup
# [2.929s] [ext: omni.kit.widget.nucleus_connector-1.1.10] startup
# [2.931s] [ext: usdrt.scenegraph-7.5.1] startup
# [2.973s] [ext: omni.usd.core-1.4.2] startup
# [2.976s] [ext: omni.kit.usd_undo-0.1.8] startup
# [2.976s] [ext: omni.graph.exec-0.9.4] startup
# [2.977s] [ext: omni.kit.actions.core-1.0.0] startup
# [2.979s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [2.981s] [ext: omni.kit.exec.core-0.13.4] startup
# [2.983s] [ext: omni.kit.commands-1.4.9] startup
# [2.988s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [3.000s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [3.007s] [ext: omni.usd-1.12.4] startup
# [3.061s] [ext: omni.kit.asset_converter-2.8.3] startup
# [3.081s] [ext: omni.volume-0.5.0] startup
# [3.089s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [3.091s] [ext: omni.index.libs-380600.1777.0] startup
# [3.091s] [ext: omni.ujitso.client-0.0.0] startup
# [3.091s] [ext: omni.index-1.0.1] startup
# [3.093s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [3.095s] [ext: omni.ui.scene-1.11.2] startup
# [3.101s] [ext: omni.hydra.rtx-1.0.0] startup
# 2025-11-10 06:47:35 [3,092ms] [Warning] [omni.log] Source: omni.hydra was already registered.
# [3.124s] [ext: omni.kit.menu.core-1.1.2] startup
# [3.125s] [ext: omni.kit.viewport.scene_camera_model-1.0.5] startup
# [3.131s] [ext: omni.kit.hydra_texture-1.4.0] startup
# [3.135s] [ext: omni.kit.menu.utils-1.7.7] startup
# [3.144s] [ext: omni.kit.widget.viewport-107.0.7] startup
# [3.149s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [3.150s] [ext: omni.kit.clipboard-1.0.5] startup
# [3.151s] [ext: omni.kit.notification_manager-1.0.9] startup
# [3.152s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [3.154s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [3.156s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [3.159s] [ext: omni.kit.widget.context_menu-1.2.4] startup
# [3.161s] [ext: omni.kit.widget.filebrowser-2.10.52] startup
# [3.165s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [3.166s] [ext: omni.kit.viewport.legacy_gizmos-1.0.16] startup
# [3.170s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [3.170s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [3.172s] [ext: omni.kit.usd.layers-2.2.0] startup
# [3.181s] [ext: omni.kit.window.filepicker-2.11.7] startup
# [3.189s] [ext: omni.kit.widget.settings-1.2.2] startup
# [3.192s] [ext: omni.kit.context_menu-1.8.3] startup
# [3.194s] [ext: omni.kit.window.file_importer-1.1.14] startup
# [3.197s] [ext: omni.kit.window.preferences-1.7.0] startup
# [3.202s] [ext: omni.kit.window.drop_support-1.0.4] startup
# [3.202s] [ext: omni.kit.raycast.query-1.0.5] startup
# [3.209s] [ext: omni.kit.material.library-1.5.15] startup
# [3.216s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [3.219s] [ext: isaacsim.core.throttling-2.0.2] startup
# [3.220s] [ext: omni.kit.viewport.window-107.0.8] startup
# [3.236s] [ext: omni.inspect-1.0.1] startup
# [3.238s] [ext: omni.kit.widget.filter-1.1.4] startup
# [3.239s] [ext: omni.graph.core-2.181.8] startup
# [3.241s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [3.242s] [ext: isaacsim.core.deprecation_manager-0.2.2] startup
# [3.243s] [ext: omni.kvdb-106.5.7] startup
# [3.245s] [ext: omni.kit.viewport.utility-1.0.18] startup
# [3.246s] [ext: omni.kit.selection-0.1.5] startup
# [3.247s] [ext: omni.kit.window.file_exporter-1.0.31] startup
# [3.248s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [3.249s] [ext: isaacsim.core.version-2.0.2] startup
# [3.250s] [ext: omni.localcache-106.5.7] startup
# [3.251s] [ext: omni.kit.menu.edit-1.1.25] startup
# [3.254s] [ext: omni.usdphysics-106.5.7] startup
# [3.257s] [ext: omni.kit.window.file-1.3.57] startup
# [3.260s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [3.261s] [ext: isaacsim.app.about-2.0.7] startup
# [3.266s] [ext: omni.kit.window.content_browser-2.10.3] startup
# [3.280s] [ext: omni.convexdecomposition-106.5.7] startup
# [3.285s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [3.286s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [3.287s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [3.290s] [ext: omni.physx.foundation-106.5.7] startup
# [3.292s] [ext: omni.kit.window.property-1.11.5] startup
# [3.295s] [ext: omni.kit.widget.stage-2.11.6] startup
# [3.306s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [3.307s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [3.308s] [ext: omni.physx.cooking-106.5.7] startup
# [3.317s] [ext: omni.kit.property.usd-4.2.16] startup
# [3.328s] [ext: omni.physx-106.5.7] startup
# [3.131s] [ext: omni.kit.hydra_texture-1.4.0] startup
# [3.135s] [ext: omni.kit.menu.utils-1.7.7] startup
# [3.144s] [ext: omni.kit.widget.viewport-107.0.7] startup
# [3.149s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [3.150s] [ext: omni.kit.clipboard-1.0.5] startup
# [3.151s] [ext: omni.kit.notification_manager-1.0.9] startup
# [3.152s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [3.154s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [3.156s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [3.159s] [ext: omni.kit.widget.context_menu-1.2.4] startup
# [3.161s] [ext: omni.kit.widget.filebrowser-2.10.52] startup
# [3.165s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [3.166s] [ext: omni.kit.viewport.legacy_gizmos-1.0.16] startup
# [3.170s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [3.170s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [3.172s] [ext: omni.kit.usd.layers-2.2.0] startup
# [3.181s] [ext: omni.kit.window.filepicker-2.11.7] startup
# [3.189s] [ext: omni.kit.widget.settings-1.2.2] startup
# [3.192s] [ext: omni.kit.context_menu-1.8.3] startup
# [3.194s] [ext: omni.kit.window.file_importer-1.1.14] startup
# [3.197s] [ext: omni.kit.window.preferences-1.7.0] startup
# [3.202s] [ext: omni.kit.window.drop_support-1.0.4] startup
# [3.202s] [ext: omni.kit.raycast.query-1.0.5] startup
# [3.209s] [ext: omni.kit.material.library-1.5.15] startup
# [3.216s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [3.219s] [ext: isaacsim.core.throttling-2.0.2] startup
# [3.220s] [ext: omni.kit.viewport.window-107.0.8] startup
# [3.236s] [ext: omni.inspect-1.0.1] startup
# [3.238s] [ext: omni.kit.widget.filter-1.1.4] startup
# [3.239s] [ext: omni.graph.core-2.181.8] startup
# [3.241s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [3.242s] [ext: isaacsim.core.deprecation_manager-0.2.2] startup
# [3.243s] [ext: omni.kvdb-106.5.7] startup
# [3.245s] [ext: omni.kit.viewport.utility-1.0.18] startup
# [3.246s] [ext: omni.kit.selection-0.1.5] startup
# [3.247s] [ext: omni.kit.window.file_exporter-1.0.31] startup
# [3.248s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [3.249s] [ext: isaacsim.core.version-2.0.2] startup
# [3.250s] [ext: omni.localcache-106.5.7] startup
# [3.251s] [ext: omni.kit.menu.edit-1.1.25] startup
# [3.254s] [ext: omni.usdphysics-106.5.7] startup
# [3.257s] [ext: omni.kit.window.file-1.3.57] startup
# [3.260s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [3.261s] [ext: isaacsim.app.about-2.0.7] startup
# [3.266s] [ext: omni.kit.window.content_browser-2.10.3] startup
# [3.280s] [ext: omni.convexdecomposition-106.5.7] startup
# [3.285s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [3.286s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [3.287s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [3.290s] [ext: omni.physx.foundation-106.5.7] startup
# [3.292s] [ext: omni.kit.window.property-1.11.5] startup
# [3.295s] [ext: omni.kit.widget.stage-2.11.6] startup
# [3.306s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [3.307s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [3.308s] [ext: omni.physx.cooking-106.5.7] startup
# [3.317s] [ext: omni.kit.property.usd-4.2.16] startup
# [3.328s] [ext: omni.physx-106.5.7] startup
# [3.342s] [ext: isaacsim.gui.property-1.0.4] startup
# [3.444s] [ext: omni.physx.stageupdate-106.5.7] startup
# [3.448s] [ext: omni.kit.numpy.common-0.1.2] startup
# [3.450s] [ext: omni.physics.tensors-106.5.7] startup
# [3.466s] [ext: omni.warp.core-1.5.0] startup
# [3.342s] [ext: isaacsim.gui.property-1.0.4] startup
# [3.444s] [ext: omni.physx.stageupdate-106.5.7] startup
# [3.448s] [ext: omni.kit.numpy.common-0.1.2] startup
# [3.450s] [ext: omni.physics.tensors-106.5.7] startup
# [3.466s] [ext: omni.warp.core-1.5.0] startup
# [3.585s] [ext: omni.isaac.dynamic_control-1.3.15] startup
# 2025-11-10 06:47:35 [3,575ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [3.592s] [ext: isaacsim.storage.native-1.0.6] startup
# [3.594s] [ext: omni.physx.tensors-106.5.7] startup
# [3.599s] [ext: isaacsim.core.utils-2.2.8] startup
# [3.602s] [ext: semantics.schema.editor-0.3.10] startup
# [3.605s] [ext: isaacsim.core.simulation_manager-0.3.3] startup
# [3.585s] [ext: omni.isaac.dynamic_control-1.3.15] startup
# 2025-11-10 06:47:35 [3,575ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [3.592s] [ext: isaacsim.storage.native-1.0.6] startup
# [3.594s] [ext: omni.physx.tensors-106.5.7] startup
# [3.599s] [ext: isaacsim.core.utils-2.2.8] startup
# [3.602s] [ext: semantics.schema.editor-0.3.10] startup
# [3.605s] [ext: isaacsim.core.simulation_manager-0.3.3] startup
# [4.856s] [ext: semantics.schema.property-1.0.5] startup
# [4.858s] [ext: isaacsim.core.cloner-1.3.4] startup
# [4.860s] [ext: omni.sensors.nv.common-2.5.0-coreapi] startup
# [4.880s] [ext: omni.graph.tools-1.79.1] startup
# [4.904s] [ext: omni.sensors.nv.materials-1.4.0-coreapi] startup
# [4.909s] [ext: omni.graph-1.140.2] startup
# [4.956s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [4.958s] [ext: omni.sensors.nv.ids-1.4.0-coreapi] startup
# [4.963s] [ext: omni.sensors.nv.lidar-2.6.3-coreapi] startup
# [4.971s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [4.977s] [ext: omni.kit.widget.graph-1.12.17] startup
# [4.989s] [ext: omni.ui_query-1.1.7] startup
# [4.991s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [4.994s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [4.996s] [ext: omni.kit.ui_test-1.3.3] startup
# [4.998s] [ext: omni.graph.scriptnode-1.40.1] startup
# [4.999s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [5.007s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [5.010s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [5.012s] [ext: omni.graph.action_core-1.1.7] startup
# [5.016s] [ext: omni.graph.image.core-0.6.0] startup
# [5.018s] [ext: omni.kit.window.material_graph-1.8.19] startup
# [5.055s] [ext: omni.graph.action_nodes-1.40.1] startup
# [4.856s] [ext: semantics.schema.property-1.0.5] startup
# [4.858s] [ext: isaacsim.core.cloner-1.3.4] startup
# [4.860s] [ext: omni.sensors.nv.common-2.5.0-coreapi] startup
# [4.880s] [ext: omni.graph.tools-1.79.1] startup
# [4.904s] [ext: omni.sensors.nv.materials-1.4.0-coreapi] startup
# [4.909s] [ext: omni.graph-1.140.2] startup
# [4.956s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [4.958s] [ext: omni.sensors.nv.ids-1.4.0-coreapi] startup
# [4.963s] [ext: omni.sensors.nv.lidar-2.6.3-coreapi] startup
# [4.971s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [4.977s] [ext: omni.kit.widget.graph-1.12.17] startup
# [4.989s] [ext: omni.ui_query-1.1.7] startup
# [4.991s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [4.994s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [4.996s] [ext: omni.kit.ui_test-1.3.3] startup
# [4.998s] [ext: omni.graph.scriptnode-1.40.1] startup
# [4.999s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [5.007s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [5.010s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [5.012s] [ext: omni.graph.action_core-1.1.7] startup
# [5.016s] [ext: omni.graph.image.core-0.6.0] startup
# [5.018s] [ext: omni.kit.window.material_graph-1.8.19] startup
# [5.055s] [ext: omni.graph.action_nodes-1.40.1] startup
# [5.060s] [ext: omni.graph.image.nodes-1.3.0] startup
# [5.062s] [ext: omni.kit.viewport.menubar.core-107.1.2] startup
# [5.100s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [5.105s] [ext: omni.graph.action-1.120.0] startup
# [5.106s] [ext: omni.graph.nodes-1.162.1] startup
# [5.118s] [ext: omni.syntheticdata-0.6.10] startup
# [5.134s] [ext: omni.kit.stage_templates-1.2.6] startup
# [5.139s] [ext: isaacsim.core.prims-0.3.7] startup
# [5.177s] [ext: omni.warp-1.5.0] startup
# [5.184s] [ext: omni.kit.window.extensions-1.4.25] startup
# [5.197s] [ext: omni.sensors.nv.wpm-2.4.0-coreapi] startup
# [5.203s] [ext: isaacsim.core.api-4.2.16] startup
# [5.060s] [ext: omni.graph.image.nodes-1.3.0] startup
# [5.062s] [ext: omni.kit.viewport.menubar.core-107.1.2] startup
# [5.100s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [5.105s] [ext: omni.graph.action-1.120.0] startup
# [5.106s] [ext: omni.graph.nodes-1.162.1] startup
# [5.118s] [ext: omni.syntheticdata-0.6.10] startup
# [5.134s] [ext: omni.kit.stage_templates-1.2.6] startup
# [5.139s] [ext: isaacsim.core.prims-0.3.7] startup
# [5.177s] [ext: omni.warp-1.5.0] startup
# [5.184s] [ext: omni.kit.window.extensions-1.4.25] startup
# [5.197s] [ext: omni.sensors.nv.wpm-2.4.0-coreapi] startup
# [5.203s] [ext: isaacsim.core.api-4.2.16] startup
# [5.270s] [ext: omni.replicator.core-1.11.35] startup
# 2025-11-10 06:47:37 [5,416ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [5.436s] [ext: isaacsim.gui.components-1.0.9] startup
# [5.445s] [ext: omni.sensors.nv.radar-2.6.1-coreapi] startup
# [5.457s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [5.462s] [ext: isaacsim.core.nodes-2.1.4] startup
# [5.270s] [ext: omni.replicator.core-1.11.35] startup
# 2025-11-10 06:47:37 [5,416ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [5.436s] [ext: isaacsim.gui.components-1.0.9] startup
# [5.445s] [ext: omni.sensors.nv.radar-2.6.1-coreapi] startup
# [5.457s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [5.462s] [ext: isaacsim.core.nodes-2.1.4] startup
# [5.471s] [ext: isaacsim.robot.surface_gripper-2.0.6] startup
# [5.482s] [ext: isaacsim.util.debug_draw-2.0.2] startup
# [5.498s] [ext: omni.sensors.tiled-0.0.6] startup
# [5.503s] [ext: omni.kit.tool.asset_importer-2.12.2] startup
# [5.524s] [ext: omni.kit.menu.create-1.0.17] startup
# [5.533s] [ext: isaacsim.robot.manipulators-3.0.4] startup
# [5.545s] [ext: isaacsim.sensors.physx-2.2.4] startup
# [5.562s] [ext: isaacsim.sensors.rtx-13.6.3] startup
# [5.583s] [ext: isaacsim.asset.importer.mjcf-2.3.3] startup
# [5.671s] [ext: omni.anim.curve.core-1.2.0] startup
# [5.471s] [ext: isaacsim.robot.surface_gripper-2.0.6] startup
# [5.482s] [ext: isaacsim.util.debug_draw-2.0.2] startup
# [5.498s] [ext: omni.sensors.tiled-0.0.6] startup
# [5.503s] [ext: omni.kit.tool.asset_importer-2.12.2] startup
# [5.524s] [ext: omni.kit.menu.create-1.0.17] startup
# [5.533s] [ext: isaacsim.robot.manipulators-3.0.4] startup
# [5.545s] [ext: isaacsim.sensors.physx-2.2.4] startup
# [5.562s] [ext: isaacsim.sensors.rtx-13.6.3] startup
# [5.583s] [ext: isaacsim.asset.importer.mjcf-2.3.3] startup
# [5.671s] [ext: omni.anim.curve.core-1.2.0] startup
# [5.694s] [ext: omni.kit.scripting-106.5.2] startup
# [5.705s] [ext: omni.graph.ui_nodes-1.40.1] startup
# [5.712s] [ext: omni.kit.manipulator.transform-106.0.1] startup
# [5.731s] [ext: omni.kit.widget.toolbar-1.7.3] startup
# [5.753s] [ext: omni.kit.manipulator.camera-106.0.3] startup
# [5.761s] [ext: isaacsim.replicator.behavior-1.0.8] startup
# [5.763s] [ext: isaacsim.simulation_app-2.4.2] startup
# [5.764s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [5.766s] [ext: omni.kit.manipulator.tool.snap-1.5.12] startup
# [5.773s] [ext: omni.kit.widget.stage_icons-1.0.6] startup
# [5.775s] [ext: omni.kit.menu.file-1.1.15] startup
# [5.777s] [ext: omni.physx.commands-106.5.7] startup
# [5.780s] [ext: omni.kit.widget.layers-1.8.2] startup
# [5.795s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [5.797s] [ext: omni.kit.window.stage-2.5.11] startup
# [5.804s] [ext: omni.fabric.commands-1.1.5] startup
# [5.810s] [ext: omni.kit.property.audio-1.0.16] startup
# [5.812s] [ext: omni.kit.usd.collect-2.2.22] startup
# [5.816s] [ext: omni.kit.stagerecorder.core-105.0.5] startup
# [5.823s] [ext: omni.kit.manipulator.prim.core-107.0.7] startup
# [5.831s] [ext: omni.kit.menu.stage-1.2.5] startup
# [5.833s] [ext: omni.kit.property.geometry-1.3.3] startup
# [5.839s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [5.842s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [5.845s] [ext: omni.kit.property.render-1.1.3] startup
# [5.847s] [ext: omni.kit.widget.zoombar-1.0.5] startup
# [5.849s] [ext: omni.kit.viewport.actions-107.0.0] startup
# [5.855s] [ext: omni.hydra.scene_api-0.1.2] startup
# [5.861s] [ext: omni.debugdraw-0.1.3] startup
# [5.865s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [5.866s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [5.868s] [ext: omni.kit.browser.core-2.3.11] startup
# [5.874s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [5.878s] [ext: omni.kit.property.transform-1.5.10] startup
# [5.884s] [ext: omni.kit.property.material-1.10.17] startup
# [5.893s] [ext: omni.kit.property.light-1.0.11] startup
# [5.694s] [ext: omni.kit.scripting-106.5.2] startup
# [5.705s] [ext: omni.graph.ui_nodes-1.40.1] startup
# [5.712s] [ext: omni.kit.manipulator.transform-106.0.1] startup
# [5.731s] [ext: omni.kit.widget.toolbar-1.7.3] startup
# [5.753s] [ext: omni.kit.manipulator.camera-106.0.3] startup
# [5.761s] [ext: isaacsim.replicator.behavior-1.0.8] startup
# [5.763s] [ext: isaacsim.simulation_app-2.4.2] startup
# [5.764s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [5.766s] [ext: omni.kit.manipulator.tool.snap-1.5.12] startup
# [5.773s] [ext: omni.kit.widget.stage_icons-1.0.6] startup
# [5.775s] [ext: omni.kit.menu.file-1.1.15] startup
# [5.777s] [ext: omni.physx.commands-106.5.7] startup
# [5.780s] [ext: omni.kit.widget.layers-1.8.2] startup
# [5.795s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [5.797s] [ext: omni.kit.window.stage-2.5.11] startup
# [5.804s] [ext: omni.fabric.commands-1.1.5] startup
# [5.810s] [ext: omni.kit.property.audio-1.0.16] startup
# [5.812s] [ext: omni.kit.usd.collect-2.2.22] startup
# [5.816s] [ext: omni.kit.stagerecorder.core-105.0.5] startup
# [5.823s] [ext: omni.kit.manipulator.prim.core-107.0.7] startup
# [5.831s] [ext: omni.kit.menu.stage-1.2.5] startup
# [5.833s] [ext: omni.kit.property.geometry-1.3.3] startup
# [5.839s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [5.842s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [5.845s] [ext: omni.kit.property.render-1.1.3] startup
# [5.847s] [ext: omni.kit.widget.zoombar-1.0.5] startup
# [5.849s] [ext: omni.kit.viewport.actions-107.0.0] startup
# [5.855s] [ext: omni.hydra.scene_api-0.1.2] startup
# [5.861s] [ext: omni.debugdraw-0.1.3] startup
# [5.865s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [5.866s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [5.868s] [ext: omni.kit.browser.core-2.3.11] startup
# [5.874s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [5.878s] [ext: omni.kit.property.transform-1.5.10] startup
# [5.884s] [ext: omni.kit.property.material-1.10.17] startup
# [5.893s] [ext: omni.kit.property.light-1.0.11] startup
# [5.896s] [ext: omni.kit.property.camera-1.0.9] startup
# [5.899s] [ext: omni.kit.browser.folder.core-1.10.1] startup
# [5.906s] [ext: omni.usdphysics.ui-106.5.7] startup
# [5.936s] [ext: omni.kit.property.bundle-1.3.2] startup
# [5.939s] [ext: omni.kit.tool.collect-2.2.16] startup
# [5.942s] [ext: omni.kit.stagerecorder.ui-105.0.6] startup
# [5.946s] [ext: isaacsim.sensors.physics-0.3.5] startup
# [5.954s] [ext: isaacsim.examples.browser-0.1.8] startup
# [5.960s] [ext: omni.physx.ui-106.5.7] startup
# [5.993s] [ext: omni.kit.viewport.menubar.camera-107.0.2] startup
# [6.000s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [6.001s] [ext: isaacsim.robot.policy.examples-4.0.3] startup
# [6.002s] [ext: isaacsim.asset.importer.urdf-2.3.10] startup
# [6.028s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [6.040s] [ext: omni.physx.demos-106.5.7] startup
# [6.060s] [ext: omni.kit.property.physx-106.5.7] startup
# [5.896s] [ext: omni.kit.property.camera-1.0.9] startup
# [5.899s] [ext: omni.kit.browser.folder.core-1.10.1] startup
# [5.906s] [ext: omni.usdphysics.ui-106.5.7] startup
# [5.936s] [ext: omni.kit.property.bundle-1.3.2] startup
# [5.939s] [ext: omni.kit.tool.collect-2.2.16] startup
# [5.942s] [ext: omni.kit.stagerecorder.ui-105.0.6] startup
# [5.946s] [ext: isaacsim.sensors.physics-0.3.5] startup
# [5.954s] [ext: isaacsim.examples.browser-0.1.8] startup
# [5.960s] [ext: omni.physx.ui-106.5.7] startup
# [5.993s] [ext: omni.kit.viewport.menubar.camera-107.0.2] startup
# [6.000s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [6.001s] [ext: isaacsim.robot.policy.examples-4.0.3] startup
# [6.002s] [ext: isaacsim.asset.importer.urdf-2.3.10] startup
# [6.028s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [6.040s] [ext: omni.physx.demos-106.5.7] startup
# [6.060s] [ext: omni.kit.property.physx-106.5.7] startup
# [6.109s] [ext: omni.kit.viewport.menubar.render-107.0.8] startup
# [6.114s] [ext: omni.kit.window.toolbar-1.6.2] startup
# [6.118s] [ext: isaacsim.robot.wheeled_robots-4.0.3] startup
# [6.128s] [ext: omni.physx.vehicle-106.5.7] startup
# [6.186s] [ext: omni.physx.graph-106.5.7] startup
# [6.227s] [ext: omni.physx.supportui-106.5.7] startup
# [6.267s] [ext: omni.physx.telemetry-106.5.7] startup
# [6.280s] [ext: omni.physx.camera-106.5.7] startup
# [6.300s] [ext: omni.physx.cct-106.5.7] startup
# [6.109s] [ext: omni.kit.viewport.menubar.render-107.0.8] startup
# [6.114s] [ext: omni.kit.window.toolbar-1.6.2] startup
# [6.118s] [ext: isaacsim.robot.wheeled_robots-4.0.3] startup
# [6.128s] [ext: omni.physx.vehicle-106.5.7] startup
# [6.186s] [ext: omni.physx.graph-106.5.7] startup
# [6.227s] [ext: omni.physx.supportui-106.5.7] startup
# [6.267s] [ext: omni.physx.telemetry-106.5.7] startup
# [6.280s] [ext: omni.physx.camera-106.5.7] startup
# [6.300s] [ext: omni.physx.cct-106.5.7] startup
# [6.320s] [ext: omni.rtx.window.settings-0.6.17] startup
# [6.336s] [ext: omni.usd.metrics.assembler-106.5.0] startup
# [6.346s] [ext: omni.kit.window.status_bar-0.1.7] startup
# [6.350s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [6.355s] [ext: omni.physx.bundle-106.5.7] startup
# [6.356s] [ext: omni.replicator.replicator_yaml-2.0.10] startup
# [6.371s] [ext: omni.rtx.settings.core-0.6.3] startup
# [6.380s] [ext: omni.usd.metrics.assembler.ui-106.5.0] startup
# [6.386s] [ext: isaacsim.asset.browser-1.3.4] startup
# [6.468s] [ext: isaacsim.gui.menu-2.0.9] startup
# 2025-11-10 06:47:38 [6,457ms] [Warning] [omni.kit.menu.utils.app_menu] add_menu_items: menu [<MenuItemDescription name:'New'>, <MenuItemDescription name:'Open'>, <MenuItemDescription name:'Re-open with New Edit Layer'>, <MenuItemDescription name:'Save'>, <MenuItemDescription name:'Save With Options'>, <MenuItemDescription name:'Save As...'>, <MenuItemDescription name:'Save Flattened As...'>, <MenuItemDescription name:'Add Reference'>, <MenuItemDescription name:'Add Payload'>, <MenuItemDescription name:'Exit'>] cannot change delegate
# [6.475s] [ext: omni.kit.ui.actions-1.0.2] startup
# [6.480s] [ext: omni.kit.window.console-0.2.14] startup
# [6.491s] [ext: isaacsim.sensors.camera-0.2.9] startup
# [6.499s] [ext: isaaclab-0.47.4] startup
# [6.320s] [ext: omni.rtx.window.settings-0.6.17] startup
# [6.336s] [ext: omni.usd.metrics.assembler-106.5.0] startup
# [6.346s] [ext: omni.kit.window.status_bar-0.1.7] startup
# [6.350s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [6.355s] [ext: omni.physx.bundle-106.5.7] startup
# [6.356s] [ext: omni.replicator.replicator_yaml-2.0.10] startup
# [6.371s] [ext: omni.rtx.settings.core-0.6.3] startup
# [6.380s] [ext: omni.usd.metrics.assembler.ui-106.5.0] startup
# [6.386s] [ext: isaacsim.asset.browser-1.3.4] startup
# [6.468s] [ext: isaacsim.gui.menu-2.0.9] startup
# 2025-11-10 06:47:38 [6,457ms] [Warning] [omni.kit.menu.utils.app_menu] add_menu_items: menu [<MenuItemDescription name:'New'>, <MenuItemDescription name:'Open'>, <MenuItemDescription name:'Re-open with New Edit Layer'>, <MenuItemDescription name:'Save'>, <MenuItemDescription name:'Save With Options'>, <MenuItemDescription name:'Save As...'>, <MenuItemDescription name:'Save Flattened As...'>, <MenuItemDescription name:'Add Reference'>, <MenuItemDescription name:'Add Payload'>, <MenuItemDescription name:'Exit'>] cannot change delegate
# [6.475s] [ext: omni.kit.ui.actions-1.0.2] startup
# [6.480s] [ext: omni.kit.window.console-0.2.14] startup
# [6.491s] [ext: isaacsim.sensors.camera-0.2.9] startup
# [6.499s] [ext: isaaclab-0.47.4] startup
# [6.723s] [ext: isaaclab_assets-0.2.3] startup
# [6.723s] [ext: isaaclab_assets-0.2.3] startup
# [6.937s] [ext: isaaclab_tasks-0.11.6] startup
# [6.937s] [ext: isaaclab_tasks-0.11.6] startup
# [8.308s] [ext: omni.kit.menu.common-1.1.9] startup
# [8.310s] [ext: isaaclab_rl-0.4.4] startup
# [8.311s] [ext: isaaclab_mimic-1.0.15] startup
# [8.312s] [ext: isaaclab.python-2.3.0] startup
# [8.314s] Simulation App Starting
# [8.308s] [ext: omni.kit.menu.common-1.1.9] startup
# [8.310s] [ext: isaaclab_rl-0.4.4] startup
# [8.311s] [ext: isaaclab_mimic-1.0.15] startup
# [8.312s] [ext: isaaclab.python-2.3.0] startup
# [8.314s] Simulation App Starting
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/isaac/.venv/lib/python3.10/site-packages/omni/extscore/omni.kit.async_engine/omni/kit/async_engine/async_engine.py:123, in _AsyncEngineDriver._patch_event_loop.<locals>.run_forever(self)
#     122 try:
# --> 123     self._run_forever_setup()
#     124     while True:
#
# File ~/isaac/.venv/lib/python3.10/site-packages/omni/extscore/omni.kit.async_engine/omni/kit/async_engine/async_engine.py:85, in _AsyncEngineDriver._patch_event_loop.<locals>._run_forever_setup(self)
#      84 self._check_closed()
# ---> 85 self._check_running()
#      86 self._set_coroutine_origin_tracking(self._debug)
#
# File /usr/lib/python3.10/asyncio/base_events.py:584, in BaseEventLoop._check_running(self)
#     583 if self.is_running():
# --> 584     raise RuntimeError('This event loop is already running')
#     585 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~/isaac/.venv/lib/python3.10/site-packages/omni/extscore/omni.kit.async_engine/omni/kit/async_engine/async_engine.py:263, in _AsyncEngineDriver.on_startup.<locals>.<lambda>(*args)
#     257 settings.set_default("/exts/omni.kit.async_engine/updateSubscriptionOrder",
#     258     omni.kit.app.UPDATE_ORDER_PYTHON_EXEC_END_UPDATE)
#     260 update_subscription_order = settings.get("/exts/omni.kit.async_engine/updateSubscriptionOrder")
#     262 self._update_end_sub = app.get_update_event_stream().create_subscription_to_pop(
# --> 263     lambda *args: self._loop.run_once(),
#     264     order=update_subscription_order,
#     265     name="[ext: omni.async_engine] AsyncEngineDriver::EndUpdate"
#     266 )
#     268 '''
#     269 Currently disabled until we update carb_sdk to better handle new subscriptions
#     270 while in the middle of processing pump of that event stream
#    (...)
#     282 )
#     283 '''
#     285 MainEventLoopWrapper.g_main_event_loop = self._loop
#
# File ~/isaac/.venv/lib/python3.10/site-packages/omni/extscore/omni.kit.async_engine/omni/kit/async_engine/async_engine.py:219, in _AsyncEngineDriver._patch_event_loop.<locals>.run_once(self)
#     217 while True:
#     218     self.stop()
# --> 219     self.run_forever()
#     221     # The proactor loop always has the self_reading_future event, so <= 1
#     222     if not self._loop_until_done or (len(self._ready) <= 1 if self._is_proactor else not self._ready):
#
# File ~/isaac/.venv/lib/python3.10/site-packages/omni/extscore/omni.kit.async_engine/omni/kit/async_engine/async_engine.py:129, in _AsyncEngineDriver._patch_event_loop.<locals>.run_forever(self)
#     127             break
#     128 finally:
# --> 129     self._run_forever_cleanup()
#
# File ~/isaac/.venv/lib/python3.10/site-packages/omni/extscore/omni.kit.async_engine/omni/kit/async_engine/async_engine.py:103, in _AsyncEngineDriver._patch_event_loop.<locals>._run_forever_cleanup(self)
#     101 events._set_running_loop(None)
#     102 self._set_coroutine_origin_tracking(False)
# --> 103 if self._old_agen_hooks is not None:
#     104     sys.set_asyncgen_hooks(*self._old_agen_hooks)
#     105     self._old_agen_hooks = None
#
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_old_agen_hooks'
# 2025-11-10 06:47:41 [9,036ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c50bd908670>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c50bd908670>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-5' coro=<MainWindow._dock_windows() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.mainwindow-1.0.3+d02c707b/omni/kit/mainwindow/scripts/main_window.py:71>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,036ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c50b713cb20>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c50b713cb20>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-6' coro=<UsdExtension.__init_stage_event() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.usd-1.12.4+d02c707b.lx64.r.cp310/omni/usd/_impl/__init__.py:29>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,036ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c50880eada0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c50880eada0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-7' coro=<NotificationManager.on_startup.<locals>.timer_fn() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.notification_manager-1.0.9+d02c707b/omni/kit/notification_manager/manager.py:120>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,036ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c506000fbe0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c506000fbe0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-8' coro=<MaterialUIExtensions.__init__.<locals>.add_menus() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.material.library-1.5.15+d02c707b/omni/kit/material/library/material_extensions.py:33>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,036ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c5060076fe0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c5060076fe0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-9' coro=<_DockingDelegate.wait_for_window() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.viewport.window-107.0.8+d02c707b/omni/kit/viewport/window/menu_entry.py:61>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,036ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c504801dcf0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c504801dcf0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-10' coro=<HotkeyTrigger._run() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.hotkeys.core-1.3.10+d02c707b/omni/kit/hotkeys/core/trigger.py:100>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,037ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c50480c7550>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c50480c7550>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-11' coro=<FileBrowserView._throttled_refresh_ui_async() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.widget.filebrowser-2.10.52+d02c707b/omni/kit/widget/filebrowser/view.py:102>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,037ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c50480c7790>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c50480c7790>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-12' coro=<FileBrowserView._throttled_refresh_ui_async() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.widget.filebrowser-2.10.52+d02c707b/omni/kit/widget/filebrowser/view.py:102>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,037ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c50480c7880>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c50480c7880>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# ...
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-49' coro=<ReplicatorYAMLExtension._autorun() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.replicator.replicator_yaml-2.0.10+lx64/omni/replicator/replicator_yaml/scripts/replicator_yaml_extension.py:110>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,040ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c4f6c32cee0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c4f6c32cee0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-50' coro=<FileBrowserItem.populate_async() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.widget.filebrowser-2.10.52+d02c707b/omni/kit/widget/filebrowser/model.py:289>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,040ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c4f6bbc2bc0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c4f6bbc2bc0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-51' coro=<PrimCaching._update_usd_cache_state() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.usd-1.12.4+d02c707b.lx64.r.cp310/omni/usd/_impl/utils.py:945>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,040ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c4f6bbd8400>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c4f6bbd8400>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-55' coro=<CameraMenuContainer.build_fn.<locals>.__hide_camera_settings_async() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.viewport.menubar.camera-107.0.2+d02c707b/omni/kit/viewport/menubar/camera/camera_menu_container.py:414>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:41 [9,069ms] [Warning] [rtx.scenedb.plugin] SceneDbContext : TLAS limit buffer size 7374781440
# 2025-11-10 06:47:41 [9,069ms] [Warning] [rtx.scenedb.plugin] SceneDbContext : TLAS limit : valid false, within: false
# 2025-11-10 06:47:41 [9,069ms] [Warning] [rtx.scenedb.plugin] SceneDbContext : TLAS limit : decrement: 167690, decrement size: 7301033856
# 2025-11-10 06:47:41 [9,069ms] [Warning] [rtx.scenedb.plugin] SceneDbContext : New limit 9748724 (slope: 439, intercept: 13179904)
# 2025-11-10 06:47:41 [9,069ms] [Warning] [rtx.scenedb.plugin] SceneDbContext : TLAS limit buffer size 4287352704
# 2025-11-10 06:47:41 [9,069ms] [Warning] [rtx.scenedb.plugin] SceneDbContext : TLAS limit : valid true, within: true
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Robots because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Robots
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Robots
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Environments because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Environments
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Environments
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for IsaacLab because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/IsaacLab
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/IsaacLab
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for People because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/People
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/People
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Props because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Props
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Props
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Samples because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Samples
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Samples
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Sensors because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Sensors
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Sensors
# [9.352s] app ready
# 2025-11-10 06:47:41 [9,396ms] [Warning] [omni.usd-abi.plugin] No setting was found for '/rtx-defaults-transient/meshlights/forceDisable'
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Robots because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Robots
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Robots
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Environments because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Environments
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Environments
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for IsaacLab because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/IsaacLab
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/IsaacLab
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for People because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/People
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/People
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Props because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Props
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Props
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Samples because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Samples
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Samples
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model] Do not load cache for Sensors because url changed:
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  - from /home/hac/isaac/isaacsim_assets/Assets/Isaac/5.0/Isaac/Sensors
# 2025-11-10 06:47:41 [9,328ms] [Warning] [omni.kit.browser.folder.core.models.folder_browser_model]  -   to https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/4.5/Isaac/Sensors
# [9.352s] app ready
# 2025-11-10 06:47:41 [9,396ms] [Warning] [omni.usd-abi.plugin] No setting was found for '/rtx-defaults-transient/meshlights/forceDisable'
# 2025-11-10 06:47:45 [13,039ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c4f51d729e0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c4f51d729e0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-70' coro=<PrimCaching._update_usd_cache_state() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.usd-1.12.4+d02c707b.lx64.r.cp310/omni/usd/_impl/utils.py:945>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:45 [13,039ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c4f51d726e0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c4f51d726e0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-71' coro=<PrimCaching._update_usd_cache_state() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.usd-1.12.4+d02c707b.lx64.r.cp310/omni/usd/_impl/utils.py:945>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# 2025-11-10 06:47:45 [13,039ms] [Error] [asyncio] Exception in callback <TaskStepMethWrapper object at 0x7c4f51d72ef0>()
# handle: <Handle <TaskStepMethWrapper object at 0x7c4f51d72ef0>()>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: Cannot enter into task <Task pending name='Task-72' coro=<_USDWatch.__delayed_prim_changed() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/isaacsim/extscache/omni.kit.viewport.menubar.core-107.1.2+d02c707b/omni/kit/viewport/menubar/core/utils/usd_watch.py:157>> while another task <Task pending name='Task-3' coro=<Kernel.dispatch_queue() running at /home/hac/isaac/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:519> cb=[_wrap_awaitable.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/gen.py:854, IOLoop.add_future.<locals>.<lambda>() at /home/hac/isaac/.venv/lib/python3.10/site-packages/tornado/ioloop.py:707]> is being executed.
# /home/hac/isaac/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment Template-Leaphand-Rot-Manager-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# [13.207s] Simulation App Startup Complete
# ✅ IsaacSim 环境已启动!
#    - Headless 模式: False
#    - 设备: cuda:0
#    - 环境数: 1
# 成功阈值: 0.2
# 成功阈值: 0.2
# ✅ 所有依赖导入完成!
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
# Cell 3: 定义场景配置并初始化

@configclass
class KinematicsTestSceneCfg(InteractiveSceneCfg):
    """运动学测试场景配置"""
    
    # 地面
    ground = sim_utils.GroundPlaneCfg()
    
    # LeapHand 机器人
    robot: ArticulationCfg = LEAP_HAND_CFG.replace(prim_path="{ENV_REGEX_NS}/Robot")

# 创建仿真上下文
sim_cfg = sim_utils.SimulationCfg(dt=0.01, device=args.device)
sim = SimulationContext(sim_cfg)

# 设置主相机视角
sim.set_camera_view(eye=[0.3, 0.3, 0.3], target=[0.0, 0.0, 0.0])

# 创建场景
scene_cfg = KinematicsTestSceneCfg(num_envs=args.num_envs, env_spacing=1.0)
scene = InteractiveScene(scene_cfg)

print(f"✅ 场景创建完成! 环境数量: {scene.num_envs}")
print(f"机器人关节数: {scene['robot'].num_joints}")
print(f"机器人 Body 数量: {scene['robot'].num_bodies}")
print(f"Body 名称: {scene['robot'].body_names}")

# %%
# Cell 4: 初始化仿真并重置场景

# 重置场景
scene.reset()

# 运行几步仿真使其稳定
print("正在初始化物理仿真...")
for _ in range(10):
    scene.write_data_to_sim()
    sim.step()
    scene.update(sim_cfg.dt)

print("✅ 仿真初始化完成!")

# 获取机器人引用 (方便后续使用)
robot = scene["robot"]

# %% [markdown]
# ---
#
# ## 运动学 API 测试区域
#
# 从此处开始可以自由交互式测试,以下 Cell 可多次执行

# %%
# Cell 5: 查看所有 Body 的位置和姿态 (World 坐标系)

# 获取所有 body 的位置和四元数姿态
body_pos_w = robot.data.body_pos_w[0]  # shape: (num_bodies, 3)
body_quat_w = robot.data.body_quat_w[0]  # shape: (num_bodies, 4), wxyz 格式

print("=" * 60)
print("LeapHand 各 Body 状态 (World 坐标系)")
print("=" * 60)

for i, body_name in enumerate(robot.body_names):
    pos = body_pos_w[i]
    quat = body_quat_w[i]
    print(f"\n{i:2d}. {body_name:20s}")
    print(f"    位置:    [{pos[0]:7.4f}, {pos[1]:7.4f}, {pos[2]:7.4f}]")
    print(f"    姿态(q): [{quat[0]:7.4f}, {quat[1]:7.4f}, {quat[2]:7.4f}, {quat[3]:7.4f}]")

# %%
# Cell 6: 获取指尖 (fingertip) 的位置 - 示例

# LeapHand 的指尖 body 名称 (根据 leap.py 中的注释)
fingertip_names = {
    "食指": "index_tip_head",
    "拇指": "thumb_tip_head", 
    "中指": "middle_tip_head",
    "无名指": "ring_tip_head"
}

print("=" * 60)
print("LeapHand 指尖位置")
print("=" * 60)

for finger_name, body_name in fingertip_names.items():
    try:
        body_idx = robot.body_names.index(body_name)
        pos = robot.data.body_pos_w[0, body_idx]
        quat = robot.data.body_quat_w[0, body_idx]
        
        print(f"\n{finger_name} ({body_name}):")
        print(f"  位置: [{pos[0]:.4f}, {pos[1]:.4f}, {pos[2]:.4f}]")
        print(f"  姿态: [{quat[0]:.4f}, {quat[1]:.4f}, {quat[2]:.4f}, {quat[3]:.4f}]")
    except ValueError:
        print(f"\n⚠️ {finger_name}: Body '{body_name}' 不存在")

# %%
# Cell 7: 坐标系转换示例 - World → Body Frame

# 获取 root (手掌) 的姿态
root_pos_w = robot.data.root_pos_w[0]  # 手掌位置 (world)
root_quat_w = robot.data.root_quat_w[0]  # 手掌姿态四元数 (world)

print("=" * 60)
print("坐标系转换测试: World → Body Frame")
print("=" * 60)

# 示例: 将食指指尖位置从 World 坐标系转换到 Body (手掌) 坐标系
try:
    fingertip_idx = robot.body_names.index("index_tip_head")
    fingertip_pos_w = robot.data.body_pos_w[0, fingertip_idx]
    fingertip_quat_w = robot.data.body_quat_w[0, fingertip_idx]
    
    # 方法1: 使用 subtract_frame_transforms
    fingertip_pos_b, fingertip_quat_b = math_utils.subtract_frame_transforms(
        root_pos_w, root_quat_w,
        fingertip_pos_w, fingertip_quat_w
    )
    
    print(f"\n手掌 (Root) - World 坐标系:")
    print(f"  位置: {root_pos_w}")
    print(f"  姿态: {root_quat_w}")
    
    print(f"\n食指指尖 - World 坐标系:")
    print(f"  位置: {fingertip_pos_w}")
    
    print(f"\n食指指尖 - Body (手掌) 坐标系:")
    print(f"  位置: {fingertip_pos_b}")
    print(f"  姿态: {fingertip_quat_b}")
    
except ValueError as e:
    print(f"⚠️ 错误: {e}")

# %%
# Cell 8: 关节角度设置与观察

# 查看当前关节位置
print("=" * 60)
print("关节状态")
print("=" * 60)

joint_pos = robot.data.joint_pos[0]  # shape: (num_joints,)
joint_vel = robot.data.joint_vel[0]

print(f"\n关节名称: {robot.joint_names}")
print(f"\n当前关节位置: {joint_pos}")
print(f"当前关节速度: {joint_vel}")

# %%
# Cell 9: 设置关节目标位置并仿真 (示例: 让食指弯曲)

# 创建目标关节位置 (全部设为 0,然后修改特定关节)
target_joint_pos = torch.zeros_like(robot.data.joint_pos)

# 设置食指相关关节 (假设前3个关节是食指)
# 注意: 需要根据实际的 joint_names 调整索引
target_joint_pos[0, :3] = torch.tensor([0.5, 0.5, 0.5])  # 弯曲食指

print(f"目标关节位置: {target_joint_pos[0]}")

# 应用关节目标
robot.set_joint_position_target(target_joint_pos)

# 仿真几步观察效果
print("\n正在仿真...")
for i in range(100):
    robot.write_data_to_sim()
    sim.step()
    robot.update(sim_cfg.dt)

print("✅ 仿真完成! 请在可视化界面观察机器人状态")

# 打印新的指尖位置
fingertip_idx = robot.body_names.index("index_tip_head")
new_pos = robot.data.body_pos_w[0, fingertip_idx]
print(f"\n食指指尖新位置: {new_pos}")

# %%
# Cell 10: 重置机器人到初始状态

# 重置环境
scene.reset()
print("✅ 机器人已重置到初始状态")

# 运行几步稳定仿真
for _ in range(10):
    scene.write_data_to_sim()
    sim.step()
    scene.update(sim_cfg.dt)

# %% [markdown]
# ---
#
# ## 清理与关闭
#
# **⚠️ 执行以下 Cell 后需重启 Kernel 才能重新开始**

# %%
# Cell 11: 关闭仿真 (可选,通常不需要在 Notebook 中执行)

# simulation_app.close()
print("如需关闭仿真,请重启 Kernel")
